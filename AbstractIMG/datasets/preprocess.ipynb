output = {}		
x = []
for i, s in enumerate([s1, s2, s3, s4, s5]):
    arr = [float(e) for e in s.split()]																																		
    for idx, v in enumerate(arr):
        num = '{0:0>3}'.format(idx+1)
        output[f'ppt{i+1}_{num}.jpg'] = v
        if float(v) > 4:
            x.append(v)
    # print(output)
print(len(x))

# with open('./MART/scores.tsv', 'w', encoding='utf-8') as f:
#     for k, v in output.items():
#         f.write(f'{k}\t{str(v)}\n')
# Out:
# 316

# %%
name_set = set()
for i in [1, 2, 4]:
     with open(f'/home/sz/AbstractIMG/datasets/Abstracts/attest{i}.txt~', 'r', encoding='utf-8') as f:
        for line in f.readlines():
            filename, label1, label2 = line.strip().split(' ')
            name_set.add(filename)

for i in [1, 2, 3, 4]:
     with open(f'/home/sz/AbstractIMG/datasets/Abstracts/attrain{i}.txt~', 'r', encoding='utf-8') as f:
        for line in f.readlines():
            filename, label1, label2 = line.strip().split(' ')
            name_set.add(filename)

print(len(name_set), name_set)

# %%
output = {}
threshold = 21. # deviant 21. MART 25.1
with open('./deviantArt/imageRatings.txt', 'r', encoding='utf-8') as f:
    f.readline()
    for line in f.readlines():
        idx, name, score1, score2 = line.split()

        s = 0 if float(score1) < threshold else 1
        output[name] = s
stat = {0:0, 1:0}
with open('./deviantArt/scores.txt', 'w', encoding='utf-8') as f:
    for k, v in output.items():
        stat[v] += 1
        f.write(f'{k}\t{v}\n')
stat
# Out:
# {0: 131, 1: 369}

# %%
import os
DATA_SET = 'MART'
os.makedirs(f'./{DATA_SET}_loader')
os.makedirs(f'./{DATA_SET}_loader/neg')
os.makedirs(f'./{DATA_SET}_loader/pos')
neg, pos = [], []
with open(f'./{DATA_SET}/scores.txt', 'r', encoding='utf-8') as f:
        for line in f.readlines():
            filename, label = line.strip().split('\t')
            label = int(label)
            if label == 0:
                neg.append(filename)
            else:
                pos.append(filename)

# win copy linux cp
for i in neg:
    # print(f'copy ./{DATA_SET}/{i} ./{DATA_SET}_loader/neg/{i}')
    os.system(f'cp ./{DATA_SET}/{i} ./{DATA_SET}_loader/neg/{i}') 

for i in pos:
    # print(f'copy ./{DATA_SET}/{i} ./{DATA_SET}_loader/pos/{i}')
    os.system(f'cp ./{DATA_SET}/{i} ./{DATA_SET}_loader/pos/{i}')
# Out:
# copy ./MART/ppt1_001.jpg ./MART_loader/neg/ppt1_001.jpg
# copy ./MART/ppt1_002.jpg ./MART_loader/neg/ppt1_002.jpg
# copy ./MART/ppt1_005.jpg ./MART_loader/neg/ppt1_005.jpg
# copy ./MART/ppt1_006.jpg ./MART_loader/neg/ppt1_006.jpg
# copy ./MART/ppt1_012.jpg ./MART_loader/neg/ppt1_012.jpg
# copy ./MART/ppt1_013.jpg ./MART_loader/neg/ppt1_013.jpg
# copy ./MART/ppt1_014.jpg ./MART_loader/neg/ppt1_014.jpg
# copy ./MART/ppt1_015.jpg ./MART_loader/neg/ppt1_015.jpg
# copy ./MART/ppt1_016.jpg ./MART_loader/neg/ppt1_016.jpg
# copy ./MART/ppt1_020.jpg ./MART_loader/neg/ppt1_020.jpg
# copy ./MART/ppt1_021.jpg ./MART_loader/neg/ppt1_021.jpg
# copy ./MART/ppt1_024.jpg ./MART_loader/neg/ppt1_024.jpg
# copy ./MART/ppt1_026.jpg ./MART_loader/neg/ppt1_026.jpg
# copy ./MART/ppt1_027.jpg ./MART_loader/neg/ppt1_027.jpg
# copy ./MART/ppt1_028.jpg ./MART_loader/neg/ppt1_028.jpg
# copy ./MART/ppt1_030.jpg ./MART_loader/neg/ppt1_030.jpg
# copy ./MART/ppt1_035.jpg ./MART_loader/neg/ppt1_035.jpg
# ...
